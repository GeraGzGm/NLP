# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences

# %%
tokenizer =  Tokenizer(lower = True, split = " ", char_level = False)
tokenizer.fit_on_texts(["Im doc 1 taco", "Im doc 2 pato"])
sequences_train = tokenizer.texts_to_sequences(["Im doc 1", "Im doc 2"])
sequences_test = tokenizer.texts_to_sequences(["Im doc 3", "Im doc 4"])

# %%
tokenizer.texts_to_matrix(["Im doc 1", "Im doc 2 "])
# Out:
# array([[0., 1., 1., 1., 0., 0., 0.],
#        [0., 1., 1., 0., 0., 1., 0.]])

# %%
sequences_train = tokenizer.texts_to_sequences(["Im doc 1", "Im doc 2 pato"])
sequences_train
# Out:
# [[1, 2, 3], [1, 2, 5, 6]]

# %%
pad_sequences(sequences_train)
# Out:
# array([[0, 1, 2, 3],
#        [1, 2, 5, 6]], dtype=int32)
